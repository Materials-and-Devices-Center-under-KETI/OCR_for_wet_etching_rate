# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

e1 = pd.read_csv('1_E.csv', index_col='cm')
e1 = e1.iloc[1:]
e1.index = [5+i for i in range(len(e1))]
e1 = e1 / 1000

w1 = pd.read_csv('1_W.csv', index_col='cm')
w1 = w1.iloc[1:]
w1.index = [5+i for i in range(len(w1))]
w1 = w1 / 1000

# %%
w2 = pd.read_csv('2_W.csv', index_col='cm')
e2 = pd.read_csv('2_E.csv', index_col='cm')
t2 = pd.read_csv('2_T.csv', index_col='cm')
b2 = pd.read_csv('2_B.csv', index_col='cm')

# %%
# drop the first column
w2 = w2.iloc[1:]
e2 = e2.iloc[1:]
t2 = t2.iloc[1:]
b2 = b2.iloc[1:]

new_index = [4,5,5.25,5.5,5.75,6,7,8,9,10,11]
w2.index = new_index
e2.index = new_index
t2.index = new_index
b2.index = new_index

w2 = w2 / 1000
e2 = e2 / 1000
t2 = t2 / 1000
b2 = b2 /1000

# %%
t3 = pd.read_csv('3_T.csv', index_col='cm')
b3 = pd.read_csv('3_B.csv', index_col='cm')

# %%
t3 = t3.iloc[1:]

new_index = [4,5,5.25,5.5,5.75,6,7,8,9,10,11]
t3.index = new_index
b3.index = new_index

t3 = t3 / 1000
b3 = b3 / 1000

# %% [markdown]
# Customize their layout

# %%
import numpy as np
fig, axs = plt.subplots()
sns.heatmap(e1, annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Thickness [um]', 'ticks':np.arange(740,761,5)}, vmax=760, vmin=740)
plt.title('E_1')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig('1_E_plot')
plt.show()

fig, axs = plt.subplots()
sns.heatmap(e1-e1.min().min(), annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Relative thickness [um]', 'ticks':np.arange(0,21,5)}, vmax=20, vmin=0)
plt.title('E_1')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig('1_E_relative_plot')
plt.show()

# %%
df_to_plot = w1
name = '1_W'
fig, axs = plt.subplots()
sns.heatmap(df_to_plot, annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Thickness [um]', 'ticks':np.arange(740,761,5)}, vmax=760, vmin=740)
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_plot')
plt.show()

fig, axs = plt.subplots()
sns.heatmap(df_to_plot-df_to_plot.min().min(), annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Relative thickness [um]', 'ticks':np.arange(0,21,5)}, vmax=20, vmin=0)
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_relative_plot')
plt.show()

# %%
df_to_plot = e2
name = '2_E'
fig, axs = plt.subplots()
sns.heatmap(df_to_plot, annot=True, cmap=plt.cm.GnBu, vmax=760, fmt=".1f",cbar_kws={'label':'Thickness [um]', 'ticks':np.arange(740,761,5)})
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_plot')
plt.show()

fig, axs = plt.subplots()
sns.heatmap(df_to_plot-df_to_plot.min().min(), annot=True, vmax=20, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Relative thickness [um]', 'ticks':np.arange(0,21,5)})
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_relative_plot')
plt.show()

# %%
df_to_plot = w2
name = '2_W'
fig, axs = plt.subplots()
sns.heatmap(df_to_plot, annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Thickness [um]', 'ticks':np.arange(740,761,5)}, vmax=760, vmin=740)
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_plot')
plt.show()

fig, axs = plt.subplots()
sns.heatmap(df_to_plot-df_to_plot.min().min(), annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Relative thickness [um]', 'ticks':np.arange(0,21,5)}, vmax=20, vmin=0)
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_relative_plot')
plt.show()

# %%
df_to_plot = t2
name = '2_T'
fig, axs = plt.subplots()
sns.heatmap(df_to_plot, annot=True, cmap=plt.cm.GnBu, fmt=".1f", vmax=760, cbar_kws={'label':'Thickness [um]', 'ticks':np.arange(740,761,5)})
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_plot')
plt.show()

fig, axs = plt.subplots()
sns.heatmap(df_to_plot-df_to_plot.min().min(), annot=True, cmap=plt.cm.GnBu, vmax=20, fmt=".1f", cbar_kws={'label':'Relative thickness [um]', 'ticks':np.arange(0,21,5)})
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_relative_plot')
plt.show()

# %%
df_to_plot = b2
name = '2_B'
fig, axs = plt.subplots()
sns.heatmap(df_to_plot, annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Thickness [um]', 'ticks':np.arange(740,761,5)}, vmax=760, vmin=740)
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_plot')
plt.show()

fig, axs = plt.subplots()
sns.heatmap(df_to_plot-df_to_plot.min().min(), annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Relative thickness [um]', 'ticks':np.arange(0,21,5)}, vmax=20, vmin=0)
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_relative_plot')
plt.show()

# %%
df_to_plot = t3
name = '3_T'
fig, axs = plt.subplots()
sns.heatmap(df_to_plot, annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Thickness [um]', 'ticks':[740,745,750,755,760]}, vmax=760, vmin=740)
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_plot')
plt.show()

fig, axs = plt.subplots()
sns.heatmap(df_to_plot-df_to_plot.min().min(), annot=True, cmap=plt.cm.GnBu, fmt=".1f", cbar_kws={'label':'Relative thickness [um]', 'ticks':np.arange(0,21,5)}, vmax=20, vmin=0)
plt.title(f'{name}')
axs.set(xlabel='X axis [cm]', ylabel='Y axis [cm]')
plt.savefig(f'{name}_relative_plot')
plt.show()
